# %% [markdown]
# # Predicting emergency department visits anchored on clinic dates
# ---
# ## Background
# Before, we built a model to predict emergency department (ED) visits anchored on treatment dates.
#
# The problem with that is the primary physicians do not interact with their patients during their treatment sessions. They only meet during their clinic visits. That is the best time for the model to nudge the physician for an intervention. Thus, we now want to build a model to predict patient's risk of ED visits prior to clinic date instead of prior to treatment session.
#
# ---

# %%
# %%capture
# %cd ~/repos/PredUCE/
# %load_ext autoreload
# %autoreload 2

# %%
import os
from dotenv import load_dotenv

import pandas as pd

from make_clinical_dataset.shared.constants import ROOT_DIR
from ml_common.summary import get_label_distribution
from preduce.acu.pipeline import prepare, train_and_eval
from preduce.shared.summarize import cohort_summary, feature_summary

pd.set_option('display.max_rows', 200)

# %%
load_dotenv()

DATE = '2025-03-29'
DATA_PATH = f'{ROOT_DIR}/data/final/data_{DATE}/processed/clinic_centered_data.parquet'
DATE_PATH = f'{ROOT_DIR}/data/final/data_{DATE}/processed/clinic_centered_dates.parquet'
SAVE_PATH = os.getenv("SAVE_PATH")

# %% [markdown]
# # Prepare the data

# %%
targ_cols = ['target_ED_30d', 'target_ED_60d', 'target_ED_90d']

# %%
df = pd.read_parquet(DATA_PATH)
out = prepare(df)
feats, targs, meta = out['feats'], out['targs'], out['meta']

# %%
get_label_distribution(targs[targ_cols], meta, with_respect_to='sessions')

# %%
get_label_distribution(targs[targ_cols], meta, with_respect_to='patients')

# %%
# Feature Characteristics
feature_summary(pd.get_dummies(feats))

# %%
# Cohort Characteristics
pd.DataFrame({'All': cohort_summary(
    pd.concat([feats, targs, meta], axis=1),
    top_cancers=feats['primary_site_desc'].value_counts().index[:5],
    targets=targ_cols
)})

# %% [markdown]
# # Train the model

# %%
# !nvidia-smi

# %%
res = train_and_eval(out, targets=targ_cols, save_path=SAVE_PATH, load_model=False)
# res = train_and_eval(out, targets=targ_cols, save_path=SAVE_PATH, load_model=True)

# %%
res['val']

# %%
res['test']

# %%
# Show all hyperparameters
from collections import defaultdict
hyperparams = defaultdict(dict)
for targ in targ_cols:
    predictor = res['models'][targ]
    model_names = predictor.model_names()
    for model_name in model_names:
        hyperparams[targ][model_name] = predictor.model_hyperparameters(model=model_name, output_format='all')
hyperparams

# %% [markdown]
# # Post-Training Analysis

# %%
# First visit vs subsequent visits
from ml_common.autogluon import evaluate
dates = pd.read_parquet(DATE_PATH).loc[meta.index]
mask = dates['treatment_date'].isna() & (meta['split'] == "Test")
first_visit = evaluate(res['models'], feats[mask], targs[mask])
first_visit

# %%
mask = dates['treatment_date'].notna() & (meta['split'] == "Test")
subseq_visits = evaluate(res['models'], feats[mask], targs[mask])
subseq_visits
